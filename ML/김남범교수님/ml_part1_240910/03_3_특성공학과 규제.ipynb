# %% [markdown]
# # 특성공학과 규제

# %% [markdown]
# <table align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/rickiepark/hg-mldl/blob/master/3-3.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />구글 코랩에서 실행하기</a>
#   </td>
# </table>

# %% [markdown]
# ## 데이터 준비

# %%
from IPython.display import Image
Image('../fig/hg_fish_MLR.png')

# %%
from IPython.display import Image
Image('../fig/hg_multiple_regression.png')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://bit.ly/perch_csv')
print(type(df))
# print(df)

# 판다수 DataFrame 자료를 numpy 배열로 변환
perch_full = df.to_numpy()
print(type(perch_full))

# 농어
print(perch_full)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.ndarray'>
# [[ 8.4   2.11  1.41]
#  [13.7   3.53  2.  ]
#  [15.    3.82  2.43]
#  [16.2   4.59  2.63]
#  [17.4   4.59  2.94]
#  [18.    5.22  3.32]
#  [18.7   5.2   3.12]
#  [19.    5.64  3.05]
#  [19.6   5.14  3.04]
#  [20.    5.08  2.77]
#  [21.    5.69  3.56]
#  [21.    5.92  3.31]
#  [21.    5.69  3.67]
#  [21.3   6.38  3.53]
#  [22.    6.11  3.41]
#  [22.    5.64  3.52]
#  [22.    6.11  3.52]
#  [22.    5.88  3.52]
#  [22.    5.52  4.  ]
#  [22.5   5.86  3.62]
#  [22.5   6.79  3.62]
#  [22.7   5.95  3.63]
#  [23.    5.22  3.63]
#  [23.5   6.28  3.72]
#  [24.    7.29  3.72]
#  [24.    6.38  3.82]
#  [24.6   6.73  4.17]
#  [25.    6.44  3.68]
#  [25.6   6.56  4.24]
#  [26.5   7.17  4.14]
#  [27.3   8.32  5.14]
#  [27.5   7.17  4.34]
#  [27.5   7.05  4.34]
#  [27.5   7.28  4.57]
#  [28.    7.82  4.2 ]
#  [28.7   7.59  4.64]
#  [30.    7.62  4.77]
#  [32.8  10.03  6.02]
#  [34.5  10.26  6.39]
#  [35.   11.49  7.8 ]
#  [36.5  10.88  6.86]
#  [36.   10.61  6.74]
#  [37.   10.84  6.26]
#  [37.   10.57  6.37]
#  [39.   11.14  7.49]
#  [39.   11.14  6.  ]
#  [39.   12.43  7.35]
#  [40.   11.93  7.11]
#  [40.   11.73  7.22]
#  [40.   12.38  7.46]
#  [40.   11.14  6.63]
#  [42.   12.8   6.87]
#  [43.   11.93  7.28]
#  [43.   12.51  7.42]
#  [43.5  12.6   8.14]
#  [44.   12.49  7.6 ]]

# %%
# http://bit.ly/perch_data

perch_weight = np.array(
    [5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0, 
     110.0, 115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0, 
     130.0, 150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0, 
     197.0, 218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0, 
     514.0, 556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0, 
     820.0, 850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0, 
     1000.0, 1000.0]
     )

# %% [markdown]
# ## Data splitting

# %%
from sklearn.model_selection import train_test_split

## input and target
train_input, test_input, train_target, test_target = train_test_split(perch_full, perch_weight, random_state=42)

# %% [markdown]
# ## 사이킷런의 변환기
# ###  다항변환 (Polynomial transform)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
# PolynomialFeatures(
#     degree=2,
#     *,
#     interaction_only=False,
#     include_bias=True,
#     order='C',
# )
# degree 2: includes x^2, y^2, xy 
# degree 3: degree 2 + x^3, y^3, xy^2, yx^2




poly = PolynomialFeatures(degree = 3)

# poly.fit: Compute number of output features.
poly.fit([[2, 3]])

# poly.transform: Transform data to polynomial features
poly.transform([[2, 3]])

print(poly.transform([[2, 3]]))
# Out:
# [[ 1.  2.  3.  4.  6.  9.  8. 12. 18. 27.]]

# %%
# include_bias=False: Intercept를 모형에서 제거
poly = PolynomialFeatures(include_bias=False)
poly.fit([[2, 3]])
print(poly.transform([[2, 3]]))
# Out:
# [[2. 3. 4. 6. 9.]]

# %% [markdown]
# ### Train feature 다항변환 하기

# %%
train_input[:10,]**2
# Out:
# array([[ 384.16  ,   26.4196,    9.2416],
#        [ 484.    ,   34.5744,   12.3904],
#        [ 349.69  ,   27.04  ,    9.7344],
#        [ 302.76  ,   21.0681,    8.6436],
#        [1296.    ,  112.5721,   45.4276],
#        [ 625.    ,   41.4736,   13.5424],
#        [1600.    ,  142.3249,   50.5521],
#        [1521.    ,  154.5049,   54.0225],
#        [1849.    ,  142.3249,   52.9984],
#        [ 484.    ,   31.8096,   12.3904]])

# %%
# mypoly = np.column_stack([train_input, train_input**2, train_input[:, 0]*train_input[:, 1], 
#                          train_input[:, 0]*train_input[:, 2], train_input[:, 1]*train_input[:, 2]])
# mypoly

# %%
poly = PolynomialFeatures(include_bias=False)

poly.fit(train_input)
train_poly = poly.transform(train_input)

# %%
print(train_poly.shape)
print(np.array(train_poly))
# Out:
# (42, 9)
# [[  19.6       5.14      3.04    384.16    100.744    59.584    26.4196
#     15.6256    9.2416]
#  [  22.        5.88      3.52    484.      129.36     77.44     34.5744
#     20.6976   12.3904]
#  [  18.7       5.2       3.12    349.69     97.24     58.344    27.04
#     16.224     9.7344]
#  [  17.4       4.59      2.94    302.76     79.866    51.156    21.0681
#     13.4946    8.6436]
#  [  36.       10.61      6.74   1296.      381.96    242.64    112.5721
#     71.5114   45.4276]
#  [  25.        6.44      3.68    625.      161.       92.       41.4736
#     23.6992   13.5424]
#  [  40.       11.93      7.11   1600.      477.2     284.4     142.3249
#     84.8223   50.5521]
#  [  39.       12.43      7.35   1521.      484.77    286.65    154.5049
#     91.3605   54.0225]
#  [  43.       11.93      7.28   1849.      512.99    313.04    142.3249
#     86.8504   52.9984]
#  [  22.        5.64      3.52    484.      124.08     77.44     31.8096
#     19.8528   12.3904]
#  [  20.        5.08      2.77    400.      101.6      55.4      25.8064
#     14.0716    7.6729]
#  [  22.        6.11      3.52    484.      134.42     77.44     37.3321
#     21.5072   12.3904]
#  [  24.        7.29      3.72    576.      174.96     89.28     53.1441
#     27.1188   13.8384]
#  [  27.5       7.17      4.34    756.25    197.175   119.35     51.4089
#     31.1178   18.8356]
#  [  43.       12.51      7.42   1849.      537.93    319.06    156.5001
#     92.8242   55.0564]
#  [  40.       11.73      7.22   1600.      469.2     288.8     137.5929
#     84.6906   52.1284]
#  [  24.        6.38      3.82    576.      153.12     91.68     40.7044
#     24.3716   14.5924]
#  [  21.        5.92      3.31    441.      124.32     69.51     35.0464
#     19.5952   10.9561]
#  [  27.5       7.05      4.34    756.25    193.875   119.35     49.7025
#     30.597    18.8356]
#  [  40.       12.38      7.46   1600.      495.2     298.4     153.2644
#     92.3548   55.6516]
#  [  32.8      10.03      6.02   1075.84    328.984   197.456   100.6009
#     60.3806   36.2404]
#  [  26.5       7.17      4.14    702.25    190.005   109.71     51.4089
#     29.6838   17.1396]
#  [  36.5      10.88      6.86   1332.25    397.12    250.39    118.3744
#     74.6368   47.0596]
#  [  13.7       3.53      2.      187.69     48.361    27.4      12.4609
#      7.06      4.    ]
#  [  22.7       5.95      3.63    515.29    135.065    82.401    35.4025
#     21.5985   13.1769]
#  [  15.        3.82      2.43    225.       57.3      36.45     14.5924
#      9.2826    5.9049]
#  [  37.       10.57      6.37   1369.      391.09    235.69    111.7249
#     67.3309   40.5769]
#  [  35.       11.49      7.8    1225.      402.15    273.      132.0201
#     89.622    60.84  ]
#  [  28.7       7.59      4.64    823.69    217.833   133.168    57.6081
#     35.2176   21.5296]
#  [  23.5       6.28      3.72    552.25    147.58     87.42     39.4384
#     23.3616   13.8384]
#  [  39.       11.14      6.     1521.      434.46    234.      124.0996
#     66.84     36.    ]
#  [  21.        5.69      3.56    441.      119.49     74.76     32.3761
#     20.2564   12.6736]
#  [  23.        5.22      3.63    529.      120.06     83.49     27.2484
#     18.9486   13.1769]
#  [  22.        5.52      4.      484.      121.44     88.       30.4704
#     22.08     16.    ]
#  [  44.       12.49      7.6    1936.      549.56    334.4     156.0001
#     94.924    57.76  ]
#  [  22.5       6.79      3.62    506.25    152.775    81.45     46.1041
#     24.5798   13.1044]
#  [  19.        5.64      3.05    361.      107.16     57.95     31.8096
#     17.202     9.3025]
#  [  37.       10.84      6.26   1369.      401.08    231.62    117.5056
#     67.8584   39.1876]
#  [  22.        6.11      3.41    484.      134.42     75.02     37.3321
#     20.8351   11.6281]
#  [  25.6       6.56      4.24    655.36    167.936   108.544    43.0336
#     27.8144   17.9776]
#  [  42.       12.8       6.87   1764.      537.6     288.54    163.84
#     87.936    47.1969]
#  [  34.5      10.26      6.39   1190.25    353.97    220.455   105.2676
#     65.5614   40.8321]]

# %% [markdown]
# ### 다항변환된 자료 확인하기

# %%
poly.get_feature_names()
# Out:
# ['x0', 'x1', 'x2', 'x0^2', 'x0 x1', 'x0 x2', 'x1^2', 'x1 x2', 'x2^2']

# %%
test_poly = poly.transform(test_input)

# %% [markdown]
# ## 다중 회귀 모델 훈련하기

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(train_poly, train_target)
print(lr.score(train_poly, train_target))
# Out:
# 0.9903183436982125

# %%
print(lr.score(test_poly, test_target))
# Out:
# 0.9714559911594155

# %% [markdown]
# ### 과적합 문제

# %%
poly = PolynomialFeatures(degree=5, include_bias=False)

poly.fit(train_input)
train_poly = poly.transform(train_input)
test_poly = poly.transform(test_input)

# %%
print(train_poly.shape)
# Out:
# (42, 55)

# %%
lr.fit(train_poly, train_target)
print(lr.score(train_poly, train_target))
# Out:
# 0.9999999999938143

# %% [markdown]
# ### Negative R^2 value

# %%
lr.score(test_poly, test_target)

print(lr.score(test_poly, test_target))
# Out:
# -144.40744532797535

# %% [markdown]
# ## 규제 (Regularization)

# %%
from IPython.display import Image
Image('../fig/hg_regularization.png')

# %% [markdown]
# ### sklearn 을 이용하여 표준화 하기

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
ss.fit(train_poly)

## test feature와 target feature 표준화
train_scaled = ss.transform(train_poly)
test_scaled = ss.transform(test_poly)

# %% [markdown]
# ### 릿지 (Ridge penalty)

# %%
from sklearn.linear_model import Ridge

## default alpha (lambda) = 1, 
ridge = Ridge()
ridge.fit(train_scaled, train_target)
print(ridge.score(train_scaled, train_target))
# Out:
# 0.9896101671037343

# %%
print(ridge.score(test_scaled, test_target))
# Out:
# 0.9790693977615386

# %%
import matplotlib.pyplot as plt

train_score = []
test_score = []

alpha_list = [0.001, 0.01, 0.1, 1, 10, 100]
for alpha in alpha_list:
    # 릿지 모델을 만듭니다
    ridge = Ridge(alpha=alpha)
    # 릿지 모델을 훈련합니다
    ridge.fit(train_scaled, train_target)
    # 훈련 점수와 테스트 점수를 저장합니다
    
    train_score.append(ridge.score(train_scaled, train_target))
    test_score.append(ridge.score(test_scaled, test_target))

# %%
## np.log10(alpha_list) = -1

plt.plot(np.log10(alpha_list), train_score, label = "Training data")
plt.plot(np.log10(alpha_list), test_score, label = "Test data")
plt.legend()
plt.xlabel("log10(alpha)")
plt.ylabel("R^2")
plt.show()

# %%
ridge = Ridge(alpha=0.1)
ridge.fit(train_scaled, train_target)

print(ridge.score(train_scaled, train_target))
print(ridge.score(test_scaled, test_target))
# Out:
# 0.9903815817570368
# 0.9827976465386896

# %% [markdown]
# ### 라쏘 (LASSO penalty)

# %%
from sklearn.linear_model import Lasso

lasso = Lasso()
lasso.fit(train_scaled, train_target)
print(lasso.score(train_scaled, train_target))
# Out:
# 0.989789897208096

# %%
print(lasso.score(test_scaled, test_target))
# Out:
# 0.9800593698421884

# %%
train_score = []
test_score = []

alpha_list = [0.001, 0.01, 0.1, 1, 10, 100]
for alpha in alpha_list:
    # 라쏘 모델을 만듭니다
    lasso = Lasso(alpha=alpha, max_iter=10000)
    # 라쏘 모델을 훈련합니다
    lasso.fit(train_scaled, train_target)
    # 훈련 점수와 테스트 점수를 저장합니다
    train_score.append(lasso.score(train_scaled, train_target))
    test_score.append(lasso.score(test_scaled, test_target))
# Out:
# C:\Users\user\Anaconda3\envs\mytf\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18778.697957792032, tolerance: 518.2793833333334
#   positive)
# C:\Users\user\Anaconda3\envs\mytf\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12972.821345401393, tolerance: 518.2793833333334
#   positive)

# %%
plt.plot(np.log10(alpha_list), train_score, label = "Training data")
plt.plot(np.log10(alpha_list), test_score, label = "Test data")
plt.legend()
plt.xlabel("log10(alpha)")
plt.ylabel("R^2")
plt.show()

# %%
lasso = Lasso(alpha=10)
lasso.fit(train_scaled, train_target)

print(lasso.score(train_scaled, train_target))
print(lasso.score(test_scaled, test_target))
# Out:
# 0.9888067471131867
# 0.9824470598706695

# %% [markdown]
# ### 계수가 0인 feature 갯수 알아보기

# %%
# print(np.sum(lasso.coef_ == 0))
# print(lasso.coef_)
# print(poly.get_feature_names())

# poly.get_feature_names()[lasso.coef_ == 0]
lasso.coef_ == 0
# poly.get_feature_names()[lasso.coef_ == 0]
myfeature = np.array(poly.get_feature_names())

myfeature[lasso.coef_ != 0]
np.sum(lasso.coef_ != 0)
# Out:
# 15
