# %% [markdown]
# AIP 속성의 이름에 대한 좀 흔한 패턴이 있나?
#
# 게시글 번호 속성명(변수) -> post_id / postId
# 생성시간 속성명 -> created_at
# 수정시간 속성명 -> updated_at
# API 키는 추가정보를 통해 파라미터로 들어간다
# 다만 API 읽기 액새스 '토큰'은 필수적으로 들어간다 - 보안성의 개선

# %%
# 18_api_3.py
# 학습 날짜 : 9월 3일 화요일
# 파이썬 프리코스 12회차
# 학습 내용 : TMDB API

# API Key와 Token은 무엇이 다른가?
# 1. API key 계정에 종속 X
# 2. Token 계정에 종속 O
# 예시, API key와 Token 재생성하는 경우
# (구) API key와 (신) API 다른 key
# (구) Token / (신) Token 하나의 계정을 대표
# 즐겨찾기, 좋아요 -> 계정의 정보

meana08906238c106a45ed556d90f551160e

# python -m pip install requests
import requests
# url = "https://api.themoviedb.org/3/movie/popular?language=ko-KR&page=1"

# 주소(url) 분리
# domain과 file path (3버전의 무비파퓰러), parameter 분리
domain = "https://api.themoviedb.org"

# 찾고 싶은 영화 번호
movie_id = 2000

# 찾고 싶은 배우 번호
person_id = 100

# path라고는 하지만 API end point라고도 한다 기능주소 # 여기만 수정해서 필요한 기능을 활용할 수 잇다.

# API 엔드포인트(API 기능 주소)
path = f"/3/movie/{movie_id}"

# path = "/3/movie/popular" 
# path = "/3/movie/top-rated"

# 파라미터, 추가 입력 정보
params = {
    "language": "ko-KR",
    "page": "1",
}

# 검색하고 싶은 영화
params["query"] = "아이언맨 1"

# 주소 조합
url = domain + path 

headers = {
    # 내가 데이터를 받고 싶은데 ~~~한 데이터 형태를 받고 싶어
    # XML / JSON
    "accept": "application/json",
    # 인증 : 인증 토큰(액세스 토큰)
    # Bearer 인증 방식을 의미
    # 02 집 전화기, 010 휴대폰, 070 인터넷 전화
    # 도로명 주소, 지번 주소
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJhMDg5MDYyMzhjMTA2YTQ1ZWQ1NTZkOTBmNTUxMTYwZSIsIm5iZiI6MTcyNTM2MTcxMi42NDY3NzUsInN1YiI6IjY2ZDZlMzk0NDYxMzA3MGMxMzUwNDE0ZCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ARhWm0dSFzBDLIua4-l9UjTiOZRsEZKG9SXncE7xef0"
}

# API 요청 함수 실행 및 응답 데이터 변수에 할당
response = requests.get(url, headers=headers, params=params)


# 응답 데이터 처리 및 변수에 할당]
# json() 메서드를 활용해서 파이썬 자료형(딕셔너리 / 리스트)으로 변환
movie_data = response.json()
print(type(response.text))

# 응답 데이터 자료형 출력
print(type(movie_data))

# 응답 데이터 출력
print(movie_data)



# API 주소를 만들 때 버전을 명시한다.
# 버전1 -> 버전2 할 때, 버전을 명시안하면
# 버전1에 대한 API가 버전2로 대체된다.
# 버전1에 대한 주소는 더이상 사용할 수 없다.
# TMDB API 버전 1을 사용하던 다른 프로그램
