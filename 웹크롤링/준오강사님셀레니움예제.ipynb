# %% [markdown]
# 크롤링에 관심있는 학습자를 위한 코랩 코드입니다.
# 정규표현식, 정적 크롤링에 beautifulsoup와 동적 크롤링에 selenium을 사용하고 있으며
# 업비트의 비트코인 자료 크롤링은 아마존 서버에 mysql을 설치한 서버를 활용했기 때문에
# 관련 코드는 않돌아갑니다.
# 전반적인 코드의 내용을 참조관점에서 보면 좋을 것 같습니다.

# %%
# 자료형

a = 1
b = 1.0
c = '1'

print(type(a))
print(type(b))
print(type(c))

# %%
a = {'1':[1,2,3],1:1}
print(type(a))
print(a)

# %%
if True:
    print(1)

for i in range(5):
    print(i)

# %%
import math

print(math.pi)

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
# 	<title>타이틀</title>
# 	<style type="text/css">
# 		p {
# 			color: red;
# 		}
# 		.abc {
# 			color: yellow;
# 		}
# 	</style>
# </head>
# <body>
# 	<h1 class="abc">제목</h1>
# 	<p style="color: blue;">문단</p>
# 	<p >문단2</p>
# 	<ul>
# 		<li>1</li>
# 		<li class="abc">2</li>
# 		<li>3</li>
# 	</ul>
# 	<span style="color: green;">abc</span>
# 	<a>def</a>
# </body>
# </html>

# %%
import requests

url = "https://news.naver.com/"

req = requests.get(url)

print(req.status_code)

print(type(req.text))

data = "<title>한국기술교육대학교</title>"

print(data[7:16])

print(len(req.text))

# %%
import requests

url = "https://search.naver.com/search.naver"
p = {'query':'파이썬'}
req = requests.get(url,params=p)

print(req.text)

# %%
url = 'https://google.com/search'
params = {'q':'파이썬'}
res = requests.get(url, params=params)
print(res.text)

# %%
import requests
url = 'https://google.com/search'
params = {'q':'파이썬'}
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

req = requests.get(url, headers=headers, params=params)
data = req.text
print(data)

# %%
import re

# 간단한 텍스트
text = "Hello, my email is example123@email.com and my phone number is 123-456-7890."

# 이메일 주소 추출
email_pattern = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
email = re.search(email_pattern, text)
if email:
    print(f"Email: {email.group()}")

# 전화번호 추출
phone_pattern = r'\b\d{3}-\d{3}-\d{4}\b'
phone = re.search(phone_pattern, text)
if phone:
    print(f"Phone: {phone.group()}")

# %%
import requests
import re

query = input("검색어를 입력하세요: ")
url = f"https://www.google.com/search?q={query}"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

response = requests.get(url, headers=headers)

# 정규표현식 패턴 설정
pattern = r'<h3 class="LC20lb MBeuO DKV0Md">(.*?)<\/h3>'
search_results = re.findall(pattern, response.text)
print(search_results)

# %%
import requests
query = input("검색어를 입력하세요: ")
url = f"https://www.google.com/search?q={query}"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

response = requests.get(url, headers=headers)

data = response.text.split('<h3 class="LC20lb MBeuO DKV0Md">')[1:]
new_data = []
for i in data:
    new_data.append(i.split('</h3>')[0])
print(new_data)

# %%
from bs4 import BeautifulSoup

data = "<html><a>하이</p>"
new_data = BeautifulSoup(data,'html.parser')
print(new_data)

# %%
import requests
from bs4 import BeautifulSoup
query = input("검색어를 입력하세요: ")
url = f"https://www.google.com/search?q={query}"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

req = requests.get(url, headers=headers)
soup = BeautifulSoup(req.text,'html.parser')

print(soup.find('h3'))

print(soup.find_all('h3'))

for i in soup.find_all('h3',attrs={'class':'LC20lb'}):
    print(i.text)

# %%
import requests
from bs4 import BeautifulSoup
query = input("검색어를 입력하세요: ")

url = f"https://www.google.com/search?q={query}"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, 'html.parser')

search_results = []
for item in soup.select('div.tF2Cxc'):
    title = item.select_one('h3').text
    link = item.select_one('a')['href']
    search_results.append({
        'title': title,
        'link': link
    })

for idx, result in enumerate(search_results, 1):
    print(f"{idx}. {result['title']}")
    print(f"   {result['link']}")
    print('-' * 50)

# %%
import requests
from bs4 import BeautifulSoup
query = input("검색어를 입력하세요: ")

url = f"https://www.google.com/search?q={query}"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

data = soup.find_all('div',attrs={'class':'yuRUbf'})

for i in data:
    print(i.find('h3',attrs={'class':'LC20lb'}).text)
    print(i.find('a')['href'])
    print('------------------------------------------')

# %%
from selenium import webdriver

chrome_driver_path = 'chromedriver'
driver = webdriver.Chrome(chrome_driver_path)
driver.get("https://www.naver.com")

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
chrome_driver_path = 'chromedriver'
driver = webdriver.Chrome()
driver.get("https://www.naver.com")

search = driver.find_element(By.ID,"query")
search.send_keys("파이썬")

search_click = driver.find_element(By.ID,"search-btn")
search_click.click()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
chrome_driver_path = 'chromedriver'
driver = webdriver.Chrome()
driver.get("https://www.naver.com")

search = driver.find_element(By.ID,"query")
search.send_keys("파이썬",Keys.ENTER)

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
chrome_driver_path = 'chromedriver'
driver = webdriver.Chrome()
driver.get("https://www.naver.com")
time.sleep(1)
search = driver.find_element(By.ID,"query")
time.sleep(2)
search.send_keys("파이썬",Keys.ENTER)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

chrome_driver_path = 'chromedriver'
driver = webdriver.Chrome()
driver.get("https://www.naver.com")
time.sleep(1)

element = driver.find_element(By.CLASS_NAME,'MyView-module__link_login___HpHMW').click()
time.sleep(1)

element = driver.find_element(By.ID,"id")
element.send_keys(여기에 아이디)
time.sleep(1)
element = driver.find_element(By.ID,"pw")
element.send_keys(여기에 비밀번호,Keys.ENTER)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

chrome_driver_path = 'chromedriver'
driver = webdriver.Chrome(chrome_driver_path)
driver.get("https://www.naver.com")

driver.execute_script("alert('경고')")

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

chrome_driver_path = 'chromedriver'
driver = webdriver.Chrome(chrome_driver_path)

driver.get("https://nid.naver.com/nidlogin.login")


driver.execute_script("document.getElementById('id').value = '';")
time.sleep(1)
driver.execute_script("document.getElementById('pw').value = '';")
time.sleep(1)

driver.find_element(By.CLASS_NAME, "btn_login").click()

# %%
import requests

url = 'https://api.upbit.com/v1/candles/minutes/1?market=KRW-BTC&to='
date = '2024-06-22T09:00:00Z'

req = requests.get(url+date)

print(req.status_code)

print(req.text)

# %%
import json

data = req.text
python_data = json.loads(data)

print(python_data)

print(type(data))
print(type(python_data))

print(python_data[0]['low_price'])

# %%
import requests

url = 'https://api.upbit.com/v1/candles/minutes/1?market=KRW-BTC&to='
date = '2024-06-22T09:00:00Z'

req = requests.get(url+date)

print(req.json())

# %% [markdown]
# CREATE TABLE market_data (
#     id INT AUTO_INCREMENT PRIMARY KEY,
#     market VARCHAR(255) NOT NULL,
#     open DECIMAL(10, 2) NOT NULL,
#     close DECIMAL(10, 2) NOT NULL,
#     date DATE NOT NULL
# );

# %%
# 값 넣기!
import pymysql

config = {
    'host': 'ls-0e7c44cd3ecf09c8b0af777d55b6619745879b64.crrdoxe0hobo.us-east-1.rds.amazonaws.com',               # MySQL 호스트 주소
    'user': 'dbmasteruser',           # MySQL 사용자 이름
    'password': 'GJ?#7`;v6e$7;WV<l]5e$F8?Q<:V~Oks',       # MySQL 비밀번호
    'database': 'crawl',  # 사용할 데이터베이스 이름
    'port': 3306                       # MySQL 포트 (기본값은 3306)
}

conn = pymysql.connect(**config)
cursor = conn.cursor()
# 삽입할 데이터
date = '2024-06-21'
text = 'datadata'
count = 2

# INSERT SQL 쿼리
sql = "INSERT INTO news_data (date, text, count) VALUES (%s, %s, %s)"  # 테이블 컬럼 값들 넣기
cursor.execute(sql, (date, text, count))

# 변경사항 커밋
conn.commit()

cursor.close()
conn.close()

# %%
# 값 조회하기 !
import pymysql

config = {
    'host': 'ls-0e7c44cd3ecf09c8b0af777d55b6619745879b64.crrdoxe0hobo.us-east-1.rds.amazonaws.com',               # MySQL 호스트 주소
    'user': 'dbmasteruser',           # MySQL 사용자 이름
    'password': 'GJ?#7`;v6e$7;WV<l]5e$F8?Q<:V~Oks',       # MySQL 비밀번호
    'database': 'crawl',  # 사용할 데이터베이스 이름
    'port': 3306                       # MySQL 포트 (기본값은 3306)
}

conn = pymysql.connect(**config)
cursor = conn.cursor()
cursor.execute('SELECT * FROM news_data')
rows = cursor.fetchall()

print(rows)
cursor.close()
conn.close()

# %%
### upbit 가격 데이터 넣기 코드

# %%
# 값 넣기!
import pymysql
import requests

url = 'https://api.upbit.com/v1/candles/minutes/1?market=KRW-BTC&to='
date = '2024-06-22T09:00:00Z'
req = requests.get(url+date)
data = req.json()[0]

config = {
    'host': 'ls-0e7c44cd3ecf09c8b0af777d55b6619745879b64.crrdoxe0hobo.us-east-1.rds.amazonaws.com',               # MySQL 호스트 주소
    'user': 'dbmasteruser',           # MySQL 사용자 이름
    'password': 'GJ?#7`;v6e$7;WV<l]5e$F8?Q<:V~Oks',       # MySQL 비밀번호
    'database': 'crawl',  # 사용할 데이터베이스 이름
    'port': 3306                       # MySQL 포트 (기본값은 3306)
}

conn = pymysql.connect(**config)
cursor = conn.cursor()
# 삽입할 데이터
market_data = data['market']
open_data = data['opening_price']
close_data =  data['trade_price']
date_data = data['candle_date_time_kst']

# INSERT SQL 쿼리
sql = "INSERT INTO market_data (market, open, close, date) VALUES (%s, %s, %s, %s)"  # 테이블 컬럼 값들 넣기
cursor.execute(sql, (market_data, open_data, close_data,date_data))

# 변경사항 커밋
conn.commit()

cursor.close()
conn.close()

# %%
#가격데이터 조회
# 값 조회하기 !
import pymysql

config = {
    'host': 'ls-0e7c44cd3ecf09c8b0af777d55b6619745879b64.crrdoxe0hobo.us-east-1.rds.amazonaws.com',               # MySQL 호스트 주소
    'user': 'dbmasteruser',           # MySQL 사용자 이름
    'password': 'GJ?#7`;v6e$7;WV<l]5e$F8?Q<:V~Oks',       # MySQL 비밀번호
    'database': 'crawl',  # 사용할 데이터베이스 이름
    'port': 3306                       # MySQL 포트 (기본값은 3306)
}

conn = pymysql.connect(**config)
cursor = conn.cursor()
cursor.execute('SELECT * FROM market_data')
rows = cursor.fetchall()

print(rows)
cursor.close()
conn.close()

# %%
import schedule
import time

def job():
    print("작업이 실행되었습니다!")

# 매 1분마다 job 함수를 실행
schedule.every(1).minutes.do(job)

# 매일 특정 시간에 job 함수를 실행 (예: 오전 10:30)
# schedule.every().day.at("10:30").do(job)

# 무한 루프를 돌며 스케줄된 작업이 있는지 확인
while True:
    schedule.run_pending()
    time.sleep(1)

# %%
schedule.every().day.at("14:00").do(job)

schedule.every().monday.do(job)       # 매주 월요일
schedule.every().wednesday.at("13:15").do(job)  # 매주 수요일 13:15
schedule.every().hour.do(job)         # 매시간
schedule.every().minute.do(job)       # 매분
schedule.every().second.do(job)       # 매초
schedule.every(10).seconds.do(job)    # 10초마다

# %%
import schedule
import time
import pymysql
import requests

config = {
    'host': 'ls-0e7c44cd3ecf09c8b0af777d55b6619745879b64.crrdoxe0hobo.us-east-1.rds.amazonaws.com',               # MySQL 호스트 주소
    'user': 'dbmasteruser',           # MySQL 사용자 이름
    'password': 'GJ?#7`;v6e$7;WV<l]5e$F8?Q<:V~Oks',       # MySQL 비밀번호
    'database': 'crawl',  # 사용할 데이터베이스 이름
    'port': 3306                       # MySQL 포트 (기본값은 3306)
}

def job():
    url = 'https://api.upbit.com/v1/candles/minutes/1?market=KRW-BTC&to='
    date = '2024-06-22T09:00:00Z'
    req = requests.get(url+date)
    data = req.json()[0]
    conn = pymysql.connect(**config)
    cursor = conn.cursor()

    market_data = data['market']
    open_data = data['opening_price']
    close_data =  data['trade_price']
    date_data = data['candle_date_time_kst']
    sql = "INSERT INTO market_data (market, open, close, date) VALUES (%s, %s, %s, %s)"  # 테이블 컬럼 값들 넣기
    cursor.execute(sql, (market_data, open_data, close_data,date_data))
    conn.commit()
    cursor.close()
    conn.close()

# 매 1분마다 job 함수를 실행
schedule.every(1).minutes.do(job)

while True:
    schedule.run_pending()
    time.sleep(1)

# %%
import schedule
import time
import pymysql
import requests

config = {
    'host': 'ls-0e7c44cd3ecf09c8b0af777d55b6619745879b64.crrdoxe0hobo.us-east-1.rds.amazonaws.com',               # MySQL 호스트 주소
    'user': 'dbmasteruser',           # MySQL 사용자 이름
    'password': 'GJ?#7`;v6e$7;WV<l]5e$F8?Q<:V~Oks',       # MySQL 비밀번호
    'database': 'crawl',  # 사용할 데이터베이스 이름
    'port': 3306                       # MySQL 포트 (기본값은 3306)
}

def job(date):
    url = 'https://api.upbit.com/v1/candles/minutes/1?market=KRW-BTC&to='
    req = requests.get(url+date)
    data = req.json()[0]
    conn = pymysql.connect(**config)
    cursor = conn.cursor()

    market_data = data['market']
    open_data = data['opening_price']
    close_data =  data['trade_price']
    date_data = data['candle_date_time_kst']
    sql = "INSERT INTO market_data (market, open, close, date) VALUES (%s, %s, %s, %s)"  # 테이블 컬럼 값들 넣기
    cursor.execute(sql, (market_data, open_data, close_data,date_data))
    conn.commit()
    cursor.close()
    conn.close()
    print('실행완료!')

# 매 1분마다 job 함수를 실행
schedule.every(1).minutes.do(job,'2024-06-22T10:00:00Z')

while True:
    schedule.run_pending()
    time.sleep(1)

# %%
import schedule
import time
import pymysql
import requests

config = {
    'host': 'ls-0e7c44cd3ecf09c8b0af777d55b6619745879b64.crrdoxe0hobo.us-east-1.rds.amazonaws.com',               # MySQL 호스트 주소
    'user': 'dbmasteruser',           # MySQL 사용자 이름
    'password': 'GJ?#7`;v6e$7;WV<l]5e$F8?Q<:V~Oks',       # MySQL 비밀번호
    'database': 'crawl',  # 사용할 데이터베이스 이름
    'port': 3306                       # MySQL 포트 (기본값은 3306)
}

def job(date):
    url = 'https://api.upbit.com/v1/candles/minutes/1?market=KRW-BTC&to='
    req = requests.get(url+date)
    data = req.json()[0]
    conn = pymysql.connect(**config)
    cursor = conn.cursor()

    market_data = data['market']
    open_data = data['opening_price']
    close_data =  data['trade_price']
    date_data = data['candle_date_time_kst']
    sql = "INSERT INTO market_data (market, open, close, date) VALUES (%s, %s, %s, %s)"  # 테이블 컬럼 값들 넣기
    cursor.execute(sql, (market_data, open_data, close_data,date_data))
    conn.commit()
    cursor.close()
    conn.close()
    print('실행완료!')

def job2():
    print(222)

def job3():
    print(333)

# 매 1분마다 job 함수를 실행
schedule.every(1).minutes.do(job,'2024-06-22T10:00:00Z')
schedule.every().monday.do(job2)       # 매주 월요일
schedule.every().wednesday.at("13:15").do(job3)  # 매주 수요일 13:15
schedule.every().hour.do(job2)

while True:
    schedule.run_pending()
    time.sleep(1)

# %%
import requests
import bs4
url = 'https://ko.wikipedia.org/wiki/'
query = '파이썬'

req = requests.get(url+query)
soup = bs4.BeautifulSoup(req.text,'html.parser')

# 1. 제목 추출
title = soup.find('caption', class_='infobox-title summary').text

# 2. 이미지 URL 추출
image_url = soup.find('td', class_='infobox-image').find('img')['src']
image_url = 'https:' + image_url  # Making sure the URL is complete

# 3. 설명 문단 추출
description_paragraphs = soup.select('div.mw-parser-output > p')
description = '\n'.join([para.get_text(strip=True) for para in description_paragraphs])

# # 4. 주요 섹션 제목과 내용 추출
sections = soup.find_all('h3')
section_data = {}
for section in sections:
    section_title = section.find('span', class_='mw-headline').text
    section_content = ''
    next_node = section.find_next_sibling()
    while next_node and next_node.name != 'h2':
        if next_node.name == 'p':
            section_content += next_node.get_text(strip=True) + '\n'
        elif next_node.name == 'ul':
            for li in next_node.find_all('li'):
                section_content += '- ' + li.get_text(strip=True) + '\n'
        next_node = next_node.find_next_sibling()
    section_data[section_title] = section_content.strip()

# Display the extracted data
print("Title:", title)
print("Image URL:", image_url)
print("Description:", description)
print("Sections:")
for sec_title, sec_content in section_data.items():
    print(f"\n{sec_title}:\n{sec_content}")

# %%
import requests
from bs4 import BeautifulSoup

url = "https://finance.naver.com/news/"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText

def send_email(subject, body, to_email):
    # Gmail SMTP 서버 설정
    smtp_server = 'smtp.gmail.com'
    smtp_port = 587
    username = 'your_email@gmail.com'
    password = 'your_password'

    # 이메일 구성
    msg = MIMEMultipart()
    msg['From'] = username
    msg['To'] = to_email
    msg['Subject'] = subject

    msg.attach(MIMEText(body, 'plain'))

    # SMTP 서버에 연결하고 이메일 발송
    try:
        server = smtplib.SMTP(smtp_server, smtp_port)
        server.starttls()  # TLS 사용 시작
        server.login(username, password)
        server.send_message(msg)
        server.quit()
        print("Email sent successfully")
    except Exception as e:
        print(f"Failed to send email: {e}")

# 예제 사용법
send_email('Test Subject', 'This is the body of the email.', 'recipient@example.com')

# %%
import requests
from bs4 import BeautifulSoup

url = "https://finance.naver.com/news/"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')


data = soup.find('div',attrs={'id':'newsMainTop'})
data = data.find('div',attrs={'class':'main_news'})

result = ""
for i in data.find_all('a'):
    result += i.text

if result.find('엔비디아') != -1:
    print('뉴스 메인에 떴습니다 엔비디아!!!')

# %%
import requests
from bs4 import BeautifulSoup

url = "https://finance.naver.com/news/"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
articles = soup.find_all('a', title=True)

# 제목만 추출하여 리스트로 저장
titles = [article['title'] for article in articles]

# 추출한 제목 출력
for idx, title in enumerate(titles, start=1):
    print(f"{idx}. {title}")

# %%
data = []

import requests
import bs4
url = 'https://news.naver.com/section/'
req = requests.get(url+'100')
soup = bs4.BeautifulSoup(req.text,'html.parser')
print(soup)

# %%
data.append(값)

# %%
data = []

import requests
import bs4
url = 'https://news.naver.com/section/'
for i in range(100,106):
    req = requests.get(url+str(i))
    soup = bs4.BeautifulSoup(req.text,'html.parser')
    for j in soup.find_all('strong',attrs={'class':'sa_text_strong'}):
        data.append(j.text)

print(data)

# %%
stopword_file_path = r'stopword.txt'
with open(stopword_file_path, 'r', encoding='utf-8') as file:
    custom_stopwords = [line.strip() for line in file]


additional_data = ['로','등','는','것','에','왜','더','것','에서','다들','이라니','의','산', '결국', '잘','[단독]']
custom_stopwords.extend(additional_data)

print(custom_stopwords)

# %%
temp = ""
for i in range(len(data)):
    word = data[i]
    word = word.replace(","," ")
    word = word.replace("…"," ")
    word = word.replace("."," ")
    word = word.replace("'"," ")
    word = word.replace('"'," ")
    word = word.replace('%'," ")
    word = word.replace('’'," ")
    word = word.replace('”'," ")
    word = word.replace('·'," ")
    word = word.replace('“'," ")
    word = word.replace('‘'," ")
    word = word.replace('?'," ")
    word = word.replace('`'," ")
    for k in range(len(custom_stopwords)):
        if word.startswith(custom_stopwords[k]):
            word = word[len(custom_stopwords[k]):]
        if word.endswith(custom_stopwords[k]):
            word = word[:-len(custom_stopwords[k])]

    temp = temp+word+" "

temp = temp.replace('  '," ")
temp = temp.replace('  '," ")
temp = temp.replace('  '," ")

print(temp)

# %%
temp_split = temp.split()


temp_dict = {}

for i in range(len(temp_split)):
    if temp_split[i] not in temp_dict:
        temp_dict[temp_split[i]]=1
    else:
        temp_dict[temp_split[i]]+=1
sorted_dict = dict(sorted(temp_dict.items(), key=lambda item: item[1])[::-1])
print(sorted_dict)

# %%
del(sorted_dict['美'])
del(sorted_dict['더'])
del(sorted_dict['또'])
del(sorted_dict['다시'])
del(sorted_dict['올해'])
del(sorted_dict['왜'])
del(sorted_dict['등'])
del(sorted_dict['안'])
del(sorted_dict['이'])
del(sorted_dict['비'])
del(sorted_dict['전'])
del(sorted_dict['성전자'])
sorted_dict['삼성전자']=2

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

fontpath = r"C:\Users\zoost\AppData\Local\Microsoft\Windows\Fonts\NanumSquareR.ttf"
# Generate a word cloud object
wordcloud = WordCloud(font_path=fontpath,width=800, height=400, background_color="white").generate_from_frequencies(sorted_dict)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide axis
plt.show()

# %%
import schedule
import time
import pymysql
import requests
import bs4

config = {
    'host': 'ls-0e7c44cd3ecf09c8b0af777d55b6619745879b64.crrdoxe0hobo.us-east-1.rds.amazonaws.com',               # MySQL 호스트 주소
    'user': 'dbmasteruser',           # MySQL 사용자 이름
    'password': 'GJ?#7`;v6e$7;WV<l]5e$F8?Q<:V~Oks',       # MySQL 비밀번호
    'database': 'crawl',  # 사용할 데이터베이스 이름
    'port': 3306                       # MySQL 포트 (기본값은 3306)
}
stopword_file_path = r'stopword.txt'
with open(stopword_file_path, 'r', encoding='utf-8') as file:
    custom_stopwords = [line.strip() for line in file]
additional_data = ['로','등','는','것','에','왜','더','것','에서','다들','이라니','의','산', '결국', '잘','[단독]']
custom_stopwords.extend(additional_data)

def job():
    data = []
    url = 'https://news.naver.com/section/'
    for i in range(100,106):
        req = requests.get(url+str(i))
        soup = bs4.BeautifulSoup(req.text,'html.parser')
        for j in soup.find_all('strong',attrs={'class':'sa_text_strong'}):
            data.append(j.text)

    temp = ""
    for i in range(len(data)):
        word = data[i]
        word = word.replace(","," ")
        word = word.replace("…"," ")
        word = word.replace("."," ")
        word = word.replace("'"," ")
        word = word.replace('"'," ")
        word = word.replace('%'," ")
        word = word.replace('’'," ")
        word = word.replace('”'," ")
        word = word.replace('·'," ")
        word = word.replace('“'," ")
        word = word.replace('‘'," ")
        word = word.replace('?'," ")
        word = word.replace('`'," ")
        for k in range(len(custom_stopwords)):
            if word.startswith(custom_stopwords[k]):
                word = word[len(custom_stopwords[k]):]
            if word.endswith(custom_stopwords[k]):
                word = word[:-len(custom_stopwords[k])]

        temp = temp+word+" "

    temp = temp.replace('  '," ")
    temp = temp.replace('  '," ")
    temp = temp.replace('  '," ")
    temp_split = temp.split()
    temp_dict = {}
    for i in range(len(temp_split)):
        if temp_split[i] not in temp_dict:
            temp_dict[temp_split[i]]=1
        else:
            temp_dict[temp_split[i]]+=1
    sorted_dict = dict(sorted(temp_dict.items(), key=lambda item: item[1])[::-1])
    del(sorted_dict['美'])
    del(sorted_dict['더'])
    del(sorted_dict['또'])
    del(sorted_dict['다시'])
    del(sorted_dict['올해'])
    del(sorted_dict['왜'])
    del(sorted_dict['등'])
    del(sorted_dict['안'])
    del(sorted_dict['이'])
    del(sorted_dict['비'])
    del(sorted_dict['전'])
    del(sorted_dict['성전자'])
    sorted_dict['삼성전자']=2
    new_data = list(sorted_dict.items())[:10]
    ctime = time.localtime()
    ftime = time.strftime('%Y-%m-%d %H:%M:%S', ctime)
    conn = pymysql.connect(**config)
    cursor = conn.cursor()

    date = ftime
    for i in range(len(new_data)):
        text = new_data[i][0]
        count = new_data[i][1]
        sql = "INSERT INTO news_data (date, text, count) VALUES (%s, %s, %s)"  # 테이블 컬럼 값들 넣기
        cursor.execute(sql, (date, text, count))

    conn.commit()
    cursor.close()
    conn.close()
    print('성공')

# 매 1분마다 job 함수를 실행
schedule.every(1).minutes.do(job)

while True:
    schedule.run_pending()
    time.sleep(1)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Chrome()
options = webdriver.ChromeOptions()
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36")
driver.get("https://nid.naver.com/nidlogin.login")

driver.execute_script("document.getElementById('id').value = '';")
time.sleep(1)
driver.execute_script("document.getElementById('pw').value = '';")
time.sleep(1)

driver.find_element(By.CLASS_NAME, "btn_login").click()
time.sleep(1)

def choice_news():
    driver.get("https://news.naver.com/")
    time.sleep(2)
    driver.get("https://news.naver.com/section/"+str(random.randint(100,105)))
    time.sleep(2)
    driver.find_element(By.CLASS_NAME, "sa_text_strong").click()

def scroll_down():
    time.sleep(2)
    random_height = random.randint(500,2000)
    driver.execute_script("window.scrollTo(0, "+str(random_height)+");")
def scroll_up():
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, 0);")
def go_home():
    time.sleep(2)
    driver.get("https://www.naver.com/")
def go_shopping():
    time.sleep(2)
    driver.get("https://shopping.naver.com/home")

import re
def find_mystore():
    scroll_down()
    time.sleep(2)
    scroll_down()
    time.sleep(2)
    scroll_down()
    time.sleep(2)
    scroll_down()
    source = driver.page_source
    soup = bs4.BeautifulSoup(source,'html.parser')
    data = soup.find_all('div',attrs={'class':re.compile(r'^product_item__')})
    for i in data:
        if i.find('div',attrs={'class':re.compile(r'^product_title__')}).text == '코카콜라 제로 355ml':
            link = i.find('a',attrs={'class':re.compile(r'^product_link__')})['href']
            driver.get(link)

def search_item(keyword):
    time.sleep(2)
    ele = driver.find_element(By.CLASS_NAME, "_combineHeader_expansion_search_inner_1VxB3") # 정규표현식으로 수정 필요
    ele.click()
    element = driver.find_element(By.ID, "input_text")
    element.send_keys(keyword, Keys.ENTER)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.common.action_chains import ActionChains
chrome_driver_path = 'chromedriver'
driver = webdriver.Chrome(chrome_driver_path)

driver.get("https://hrdi.koreatech.ac.kr/?m1=member_login")
time.sleep(1)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.common.action_chains import ActionChains
chrome_driver_path = 'chromedriver'
driver = webdriver.Chrome(chrome_driver_path)

driver.get("https://hrdi.koreatech.ac.kr/?m1=member_login")
time.sleep(1)

driver.execute_script("document.getElementById('idCon').value = '';")
time.sleep(1)
driver.execute_script("document.getElementById('pwdCon').value = '';")
time.sleep(1)

driver.find_element(By.CLASS_NAME, "member_login_btn").click()

time.sleep(2)
driver.get("https://hrdi.koreatech.ac.kr/?m1=page&menu_id=4")
time.sleep(2)


element = driver.find_element(By.CLASS_NAME,'search_text')
element.send_keys('인공지능',Keys.ENTER)
time.sleep(2)

element = driver.find_element(By.CLASS_NAME,'application_btn').click()
time.sleep(2)

element = driver.find_element(By.CLASS_NAME,'enroll_courses').click()
time.sleep(2)

driver.find_element(By.CLASS_NAME,"alert_cancel_button").click()
